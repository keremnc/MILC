Compressed v2 in 131.125000 seconds [ratio=3.341099]
Compressed v3 in 132.703125 seconds [ratio=3.862732]
Compressed v4 in 133.218750 seconds [ratio=3.862726]
Compressed v5 in 133.500000 seconds [ratio=3.862726]
SIMDized in 14.062500 seconds [ratio=1.000000]
V1 took 57.187500 seconds [46661328 bytes]
V2 took 51.468750 seconds [40171732 bytes]
V3 took 203.984375 seconds [34746836 bytes]
V4 took 151.312500 seconds [34746896 bytes]
V5 took 48.734375 seconds [34746896 bytes]
Uncompressed took 62.781250 seconds [134217728 bytes]
SIMD-ized took 47.218750 seconds [134217728 bytes]
'''

ratios = {}
us_p_op = {}
comp_speeds = {}

p = 0
ops = 0
for line in data.split('\n'):
    if 'TIMINGS FOR' in line:
        p = int(line.split("p=")[1].split(" ")[0])
    if 'Operations=' in line:
        ops = int(line.split('Operations=')[1].split(' ')[0])
    if 'Compressed' in line:
        comp_speed = float(line.split("in ")[1].split(" seconds")[0])
        comp_ratio = float(line.split("ratio=")[1][:-1])
        v = line.split("Compressed ")[1].split(" in")[0].lower()
        if v not in ratios:
            ratios[v] = {}
        ratios[v][2**p] = comp_ratio
        
        if v not in comp_speeds:
            comp_speeds[v] = {}
        comp_speeds[v][2**p] = (comp_speed / ops) * 1_000_000_000
    if 'took' in line:
        total_time = float(line.split('took ')[1].split(' ')[0])
        v = line.split(' took')[0].lower()
        # ops operations in total_time seconds
        # total_time / ops seconds/op
        if v not in us_p_op:
            us_p_op[v] = {}
        us_p_op[v][2**p] = (total_time / ops) * 1_000_000_000
# Out:
# {'v1': {65536: 90.12152707683256,
#   131072: 105.27847757551582,
#   262144: 115.07503971914198,
#   524288: 108.62494475645666,
#   1048576: 104.71151558609968,
#   2097152: 102.81923315509995,
#   4194304: 80.10466473598434,
#   8388608: 84.01491817588237,
#   16777216: 92.63393151301996,
#   33554432: 99.1945232987784},
#  'v2': {65536: 90.12152707683256,
#   131072: 84.22278206041267,
#   262144: 87.29830599383186,
#   524288: 84.23975307643579,
#   1048576: 70.15671544268679,
#   2097152: 89.77874504762386,
#   4194304: 86.26656202336775,
#   8388608: 82.63762443529414,
#   16777216: 92.10998393658885,
#   33554432: 89.27507096890056},
#  'v3': {65536: 217.0126372010128,
#   131072: 242.14049842368638,
#   262144: 268.24388569013786,
#   524288: 254.49272771512705,
#   1048576: 270.78397930565376,
#   2097152: 253.68764941390032,
#   4194304: 270.41249249632585,
#   8388608: 286.0180001288236,
#   16777216: 344.60032101874,
#   33554432: 353.82090209441316},
# ...

# %%
labels = []
for v in ratios:
    if v != 'v3' and v != 'v4':
        x, y = zip(*sorted(ratios[v].items()))
        plt.plot(x, y, linewidth=4.0)
        labels.append(v)
plt.legend(labels, loc='center right')
plt.title('Compression Ratio by Version')
plt.xlabel('Element Count', fontsize=22)
plt.ylabel('Compression Ratio', fontsize=22)
plt.xscale('log')
plt.show()

# %%
labels = []
for v in comp_speeds:
    x, y = zip(*sorted(comp_speeds[v].items()))
    plt.plot(x, y, linewidth=4.0)
    labels.append(v)
plt.legend(labels, loc='center right')
plt.title('Compression Performance')
plt.xlabel('Element Count', fontsize=22)
plt.ylabel('Element Compression Latency (ns)', fontsize=22)
plt.xscale('log')
plt.show()

# %%
labels = []
for v in us_p_op:
    x, y = zip(*sorted(us_p_op[v].items()))
    plt.plot(x, y, linewidth=4.0)
    labels.append(v)
plt.legend(labels, loc='upper left')
plt.title('Membership Testing Performance')
plt.xlabel('Element Count', fontsize=22)
plt.ylabel('Operation Latency (ns)', fontsize=22)
plt.xscale('log')
plt.show()
