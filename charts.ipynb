# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"]=20,10
plt.rcParams['font.size'] = 20
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": ["Helvetica"]})

# %%
data = '''
===== TIMINGS FOR p=16 =====
===== Operations=708273 =====
Processing 65536 elements [262144 bytes]
Compressed v1 in 0.015625 seconds [ratio=2.895915]
Compressed v2 in 0.250000 seconds [ratio=3.345551]
Compressed v3 in 0.250000 seconds [ratio=3.871456]
Compressed v4 in 0.343750 seconds [ratio=3.868028]
Compressed v5 in 0.359375 seconds [ratio=3.868028]
SIMDized in 0.015625 seconds [ratio=1.000000]
V1 took 0.078125 seconds [90522 bytes]
V2 took 0.078125 seconds [78356 bytes]
V3 took 0.093750 seconds [67712 bytes]
V4 took 0.140625 seconds [67772 bytes]
V5 took 0.093750 seconds [67772 bytes]
Uncompressed took 0.062500 seconds [262144 bytes]
SIMD-ized took 0.031250 seconds [262144 bytes]
===== TIMINGS FOR p=17 =====
===== Operations=1908964 =====
Processing 131072 elements [524288 bytes]
Compressed v1 in 0.000000 seconds [ratio=2.884158]
Compressed v2 in 0.515625 seconds [ratio=3.345551]
Compressed v3 in 0.484375 seconds [ratio=3.876150]
Compressed v4 in 0.593750 seconds [ratio=3.874431]
Compressed v5 in 0.609375 seconds [ratio=3.874431]
SIMDized in 0.031250 seconds [ratio=1.000000]
V1 took 0.203125 seconds [181782 bytes]
V2 took 0.203125 seconds [156712 bytes]
V3 took 0.265625 seconds [135260 bytes]
V4 took 0.406250 seconds [135320 bytes]
V5 took 0.250000 seconds [135320 bytes]
Uncompressed took 0.140625 seconds [524288 bytes]
SIMD-ized took 0.109375 seconds [524288 bytes]
===== TIMINGS FOR p=18 =====
===== Operations=3123575 =====
Processing 262144 elements [1048576 bytes]
Compressed v1 in 0.000000 seconds [ratio=2.883793]
Compressed v2 in 1.015625 seconds [ratio=3.341308]
Compressed v3 in 1.046875 seconds [ratio=3.860310]
Compressed v4 in 1.046875 seconds [ratio=3.859457]
Compressed v5 in 1.046875 seconds [ratio=3.859457]
SIMDized in 0.078125 seconds [ratio=1.000000]
V1 took 0.390625 seconds [363610 bytes]
V2 took 0.343750 seconds [313822 bytes]
V3 took 0.453125 seconds [271630 bytes]
V4 took 0.687500 seconds [271690 bytes]
V5 took 0.437500 seconds [271690 bytes]
Uncompressed took 0.250000 seconds [1048576 bytes]
SIMD-ized took 0.171875 seconds [1048576 bytes]
===== TIMINGS FOR p=19 =====
===== Operations=8739555 =====
Processing 524288 elements [2097152 bytes]
Compressed v1 in 0.000000 seconds [ratio=2.878386]
Compressed v2 in 1.953125 seconds [ratio=3.342991]
Compressed v3 in 2.062500 seconds [ratio=3.864436]
Compressed v4 in 2.234375 seconds [ratio=3.864009]
Compressed v5 in 2.109375 seconds [ratio=3.864009]
SIMDized in 0.156250 seconds [ratio=1.000000]
V1 took 1.140625 seconds [728586 bytes]
V2 took 0.984375 seconds [627328 bytes]
V3 took 1.218750 seconds [542680 bytes]
V4 took 2.125000 seconds [542740 bytes]
V5 took 1.156250 seconds [542740 bytes]
Uncompressed took 0.703125 seconds [2097152 bytes]
SIMD-ized took 0.531250 seconds [2097152 bytes]
===== TIMINGS FOR p=20 =====
===== Operations=33517301 =====
Processing 1048576 elements [4194304 bytes]
Compressed v1 in 0.015625 seconds [ratio=2.877119]
Compressed v2 in 4.093750 seconds [ratio=3.341191]
Compressed v3 in 4.203125 seconds [ratio=3.861703]
Compressed v4 in 4.218750 seconds [ratio=3.861490]
Compressed v5 in 4.218750 seconds [ratio=3.861490]
SIMDized in 0.343750 seconds [ratio=1.000000]
V1 took 4.812500 seconds [1457814 bytes]
V2 took 3.968750 seconds [1255332 bytes]
V3 took 4.687500 seconds [1086128 bytes]
V4 took 8.343750 seconds [1086188 bytes]
V5 took 4.359375 seconds [1086188 bytes]
Uncompressed took 2.859375 seconds [4194304 bytes]
SIMD-ized took 2.000000 seconds [4194304 bytes]
===== TIMINGS FOR p=21 =====
===== Operations=37699263 =====
Processing 2097152 elements [8388608 bytes]
Compressed v1 in 0.031250 seconds [ratio=2.876564]
Compressed v2 in 8.218750 seconds [ratio=3.340771]
Compressed v3 in 8.312500 seconds [ratio=3.863176]
Compressed v4 in 8.296875 seconds [ratio=3.863069]
Compressed v5 in 8.281250 seconds [ratio=3.863069]
SIMDized in 0.765625 seconds [ratio=1.000000]
V1 took 5.312500 seconds [2916190 bytes]
V2 took 4.468750 seconds [2510980 bytes]
V3 took 5.421875 seconds [2171428 bytes]
V4 took 9.453125 seconds [2171488 bytes]
V5 took 5.203125 seconds [2171488 bytes]
Uncompressed took 3.421875 seconds [8388608 bytes]
SIMD-ized took 2.625000 seconds [8388608 bytes]
===== TIMINGS FOR p=22 =====
===== Operations=58566227 =====
Processing 4194304 elements [16777216 bytes]
Compressed v1 in 0.031250 seconds [ratio=2.879473]
Compressed v2 in 16.218750 seconds [ratio=3.342213]
Compressed v3 in 16.562500 seconds [ratio=3.864653]
Compressed v4 in 16.734375 seconds [ratio=3.864600]
Compressed v5 in 17.062500 seconds [ratio=3.864600]
SIMDized in 1.546875 seconds [ratio=1.000000]
V1 took 8.093750 seconds [5826488 bytes]
V2 took 7.437500 seconds [5019792 bytes]
V3 took 8.890625 seconds [4341196 bytes]
V4 took 15.484375 seconds [4341256 bytes]
V5 took 8.546875 seconds [4341256 bytes]
Uncompressed took 5.734375 seconds [16777216 bytes]
SIMD-ized took 4.187500 seconds [16777216 bytes]
===== TIMINGS FOR p=23 =====
===== Operations=123202340 =====
Processing 8388608 elements [33554432 bytes]
Compressed v1 in 0.093750 seconds [ratio=2.875878]
Compressed v2 in 32.828125 seconds [ratio=3.341540]
Compressed v3 in 33.453125 seconds [ratio=3.863732]
Compressed v4 in 33.187500 seconds [ratio=3.863705]
Compressed v5 in 33.203125 seconds [ratio=3.863705]
SIMDized in 3.109375 seconds [ratio=1.000000]
V1 took 17.593750 seconds [11667544 bytes]
V2 took 16.250000 seconds [10041606 bytes]
V3 took 19.187500 seconds [8684462 bytes]
V4 took 35.015625 seconds [8684522 bytes]
V5 took 17.281250 seconds [8684522 bytes]
Uncompressed took 13.625000 seconds [33554432 bytes]
SIMD-ized took 9.843750 seconds [33554432 bytes]
===== TIMINGS FOR p=24 =====
===== Operations=513471160 =====
Processing 16777216 elements [67108864 bytes]
Compressed v1 in 0.187500 seconds [ratio=2.876932]
Compressed v2 in 65.609375 seconds [ratio=3.341585]
Compressed v3 in 66.500000 seconds [ratio=3.863084]
Compressed v4 in 66.562500 seconds [ratio=3.863070]
Compressed v5 in 66.671875 seconds [ratio=3.863070]
SIMDized in 6.281250 seconds [ratio=1.000000]
V1 took 80.500000 seconds [23326536 bytes]
V2 took 66.781250 seconds [20082942 bytes]
V3 took 80.171875 seconds [17371838 bytes]
V4 took 151.203125 seconds [17371898 bytes]
V5 took 69.203125 seconds [17371898 bytes]
Uncompressed took 56.484375 seconds [67108864 bytes]
SIMD-ized took 40.765625 seconds [67108864 bytes]
===== TIMINGS FOR p=25 =====
===== Operations=653039319 =====
Processing 33554432 elements [134217728 bytes]
Compressed v1 in 0.375000 seconds [ratio=2.875700]
Compressed v2 in 131.515625 seconds [ratio=3.341392]
Compressed v3 in 133.562500 seconds [ratio=3.862514]
Compressed v4 in 133.515625 seconds [ratio=3.862508]
Compressed v5 in 133.093750 seconds [ratio=3.862508]
SIMDized in 14.000000 seconds [ratio=1.000000]
V1 took 101.031250 seconds [46673060 bytes]
V2 took 89.390625 seconds [40168208 bytes]
V3 took 105.578125 seconds [34748796 bytes]
V4 took 193.828125 seconds [34748856 bytes]
V5 took 85.203125 seconds [34748856 bytes]
Uncompressed took 75.109375 seconds [134217728 bytes]
SIMD-ized took 56.281250 seconds [134217728 bytes]
'''

ratios = {}
us_p_op = {}
comp_speeds = {}

p = 0
ops = 0
for line in data.split('\n'):
    if 'TIMINGS FOR' in line:
        p = int(line.split("p=")[1].split(" ")[0])
    if 'Operations=' in line:
        ops = int(line.split('Operations=')[1].split(' ')[0])
    if 'Compressed' in line:
        comp_speed = float(line.split("in ")[1].split(" seconds")[0])
        comp_ratio = float(line.split("ratio=")[1][:-1])
        v = line.split("Compressed ")[1].split(" in")[0].lower()
        if v not in ratios:
            ratios[v] = {}
        ratios[v][2**p] = comp_ratio
        
        if v not in comp_speeds:
            comp_speeds[v] = {}
        comp_speeds[v][2**p] = (comp_speed / ops) * 1_000_000_000
    if 'took' in line:
        total_time = float(line.split('took ')[1].split(' ')[0])
        v = line.split(' took')[0].lower()
        # ops operations in total_time seconds
        # total_time / ops seconds/op
        if v not in us_p_op:
            us_p_op[v] = {}
        us_p_op[v][2**p] = (total_time / ops) * 1_000_000_000

# %%
mappings = {
    'v1': 'Static Partitioning',
    'v2': 'Dynamic Partitioning',
    'v3': 'In-block Compression',
    'v4': 'Cache-conscious Compression',
    'v5': 'CPU Optimizations',
    'uncompressed': 'Uncompressed',
    'simd-ized': 'Uncompresed w/ SIMD'
}

# %%
labels = []
for v in ratios:
    if v != 'v3' and v != 'v4':
        x, y = zip(*sorted(ratios[v].items()))
        plt.plot(x, y, linewidth=4.0)
        if v in mappings:
            v = mappings[v]
        labels.append(v)
plt.legend(labels, loc='center right')
plt.title('Compression Ratio by Version')
plt.xlabel('Element Count', fontsize=22)
plt.ylabel('Compression Ratio', fontsize=22)
plt.xscale('log')
plt.show()
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
labels = []
for v in comp_speeds:
    x, y = zip(*sorted(comp_speeds[v].items()))
    plt.plot(x, y, linewidth=4.0)
    if v in mappings:
        v = mappings[v]
    labels.append(v)
plt.legend(labels, loc='upper right')
plt.title('Compression Performance')
plt.xlabel('Element Count', fontsize=22)
plt.ylabel('Element Compression Latency (ns)', fontsize=22)
plt.xscale('log')
plt.show()

# %%
labels = []
for v in us_p_op:
    x, y = zip(*sorted(us_p_op[v].items()))
    plt.plot(x, y, linewidth=4.0)
    if v in mappings:
        v = mappings[v]
    labels.append(v)
plt.legend(labels, loc='upper left')
plt.title('Membership Testing Performance')
plt.xlabel('Element Count', fontsize=22)
plt.ylabel('Operation Latency (ns)', fontsize=22)
plt.xscale('log')
plt.show()
